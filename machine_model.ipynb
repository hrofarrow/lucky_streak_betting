# %%
# Set the seed value for the notebook so the results are reproducible
from numpy.random import seed
seed(1)

# %%
import os
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.utils import to_categorical
from tensorflow.keras.layers import Dense

# %%
import numpy as np
import pandas as pd

# %%
names = ['field', 'game_result', 'side_line', 'line', 'odds']
df = pd.read_csv(
    "csv/Stats.csv", names=names)

# %%
df
# Out:
#       field  game_result  side_line  line  odds
# 0     field  game_result  side_line  line  odds
# 1         1            L       -155   8.5  -106
# 2         1            W       -155   8.5  -116
# 3         1            W       -145     8  -106
# 4         1            W       -120     9   107
# ...     ...          ...        ...   ...   ...
# 4686      1            W       -183   8.5  -106
# 4687      1            W       -180     7   102
# 4688      1            W       -117     8   100
# 4689      0            W       -132   7.5   102
# 4690      0            W        119     8  -113
#
# [4691 rows x 5 columns]

# %%
# Apply one-hot encoding for the column with string"

# Step 0: Reformat data
data = df.values
X = data[:, 0:5]
y = data[:, 1]

print(X)
print(y)
# Out:
# [['field' 'game_result' 'side_line' 'line' 'odds']
#  ['1' 'L' '-155' '8.5' '-106']
#  ['1' 'W' '-155' '8.5' '-116']
#  ...
#  ['1' 'W' '-117' '8' '100']
#  ['0' 'W' '-132' '7.5' '102']
#  ['0' 'W' '119' '8' '-113']]
# ['game_result' 'L' 'W' ... 'W' 'W' 'W']

# %%
from sklearn.preprocessing import LabelEncoder

# Step 1: Label-encode data set
label_encoder = LabelEncoder()
label_encoder.fit(y)
encoded_y = label_encoder.transform(y)

# %%
for label, original_class in zip(encoded_y, y):
    print('Original Status: ' + str(original_class))
    print('Encoded Label: ' + str(label))
    print('-' * 12)
# Out:
# -------
# Original Status: W
# Encoded Label: 1
# ------------
# Original Status: L
# Encoded Label: 0
# ------------
# Original Status: W
# Encoded Label: 1
# ------------
# Original Status: W
# Encoded Label: 1
# ------------
# Original Status: L
# Encoded Label: 0
# ------------
# Original Status: W
# Encoded Label: 1
# ------------
# Original Status: L
# Encoded Label: 0
# ------------
# Original Status: W
# Encoded Label: 1
# ------------
# Original Status: W
# Encoded Label: 1
# ------------
# Original Status: L
# Encoded Label: 0
# ------------
# Original Status: W
# Encoded Label: 1
# ------------
# Original Status: W
# Encoded Label: 1
# ------------
# Original Status: W
# Encoded Label: 1
# ------------
# Original Status: L
# Encoded Label: 0
# ------------
# Original Status: W
# Encoded Label: 1
# ------------
# Original Status: L
# Encoded Label: 0
# ------------
# Original Status: W
# Encoded Label: 1
# ------------
# Original Status: L
# Encoded Label: 0
# ------------
# Original Status: L
# Encoded Label: 0
# ------------
# Original Status: L
# Encoded Label: 0
# ------------
# Original Status: L
# Encoded Label: 0
# ------------
# Original Status: L
# Encoded Label: 0
# ------------
# Original Status: L
# Encoded Label: 0
# ------------
# Original Status: W
# Encoded Label: 1
# ------------
# Original Status: W
# Encoded Label: 1
# ------------
# Original Status: L
# Encoded Label: 0
# ------------
# Original Status: L
# Encoded Label: 0
# ------------
# Original Status: L
# Encoded Label: 0
# ------------
# Original Status: W
# Encoded Label: 1
# ------------
# Original Status: W
# Encoded Label: 1
# ------------
# Original Status: W
# Encoded Label: 1
# ------------
# Original Status: W
# Encoded Label: 1
# ------------
# Original Status: L
# Encoded Label: 0
# ------------
# Original Status: W
# Encoded Label: 1
# ------------
# Original Status: L
# Encoded Label: 0
# ------------
# Original Status: W
# Encoded Label: 1
# ------------
# Original Status: W
# Encoded Label: 1
# ------------
# Original Status: W
# Encoded Label: 1
# ------------
# Original Status: W
# Encoded Label: 1
# ------------
# Original Status: L
# Encoded Label: 0
# ------------
# Original Status: W
# Encoded Label: 1
# ------------
# Original Status: L
# Encoded Label: 0
# ------------
# Original Status: W
# Encoded Label: 1
# ------------
# Original Status: L
# Encoded Label: 0
# ------------
# Original Status: W
# Encoded Label: 1
# ------------
# Original Status: W
# Encoded Label: 1
# ------------
# Original Status: W
# Encoded Label: 1
# ------------
# Original Status: L
# Encoded Label: 0
# ------------
# Original Status: W
# Encoded Label: 1
# ------------
# Original Status: W
# Encoded Label: 1
# ------------
# Original Status: W
# Encoded Label: 1
# ------------
# Original Status: W
# Encoded Label: 1
# ------------
# Original Status: W
# Encoded Label: 1
# ------------
# Original Status: W
# Encoded Label: 1
# ------------
# Original Status: W
# Encoded Label: 1
# ------------
# Original Status: W
# Encoded Label: 1
# ------------
# Original Status: W
# Encoded Label: 1
# ------------
# Original Status: L
# Encoded Label: 0
# ------------
# Original Status: W
# Encoded Label: 1
# ------------
# Original Status: W
# Encoded Label: 1
# ------------
# Original Status: L
# Encoded Label: 0
# ------------
# Original Status: L
# Encoded Label: 0
# ------------
# Original Status: W
# Encoded Label: 1
# ------------
# Original Status: W
# Encoded Label: 1
# ------------
# Original Status: W
# Encoded Label: 1
# ------------
# Original Status: L
# Encoded Label: 0
# ------------
# Original Status: L
# Encoded Label: 0
# ------------
# Original Status: L
# Encoded Label: 0
# ------------
# Original Status: L
# Encoded Label: 0
# ------------
# Original Status: L
# Encoded Label: 0
# ------------
# Original Status: W
# Encoded Label: 1
# ------------
# Original Status: L
# Encoded Label: 0
# ------------
# Original Status: L
# Encoded Label: 0
# ------------
# Original Status: W
# Encoded Label: 1
# ------------
# Original Status: L
# Encoded Label: 0
# ------------
# Original Status: W
# Encoded Label: 1
# ------------
# Original Status: L
# Encoded Label: 0
# ------------
# Original Status: W
# Encoded Label: 1
# ------------
# Original Status: W
# Encoded Label: 1
# ------------
# Original Status: L
# Encoded Label: 0
# ------------
# Original Status: W
# Encoded Label: 1
# ------------
# Original Status: L
# Encoded Label: 0
# ------------
# Original Status: L
# Encoded Label: 0
# ------------
# Original Status: W
# Encoded Label: 1
# ------------
# Original Status: W
# Encoded Label: 1
# ------------
# Original Status: L
# Encoded Label: 0
# ------------
# Original Status: L
# Encoded Label: 0
# ------------
# Original Status: L
# Encoded Label: 0
# ------------
# Original Status: W
# Encoded Label: 1
# ------------
# Original Status: W
# Encoded Label: 1
# ------------
# Original Status: L
# Encoded Label: 0
# ------------
# Original Status: W
# Encoded Label: 1
# ------------
# Original Status: L
# Encoded Label: 0
# ------------
# Original Status: L
# Encoded Label: 0
# ------------
# Original Status: L
# Encoded Label: 0
# ------------
# Original Status: L
# Encoded Label: 0
# ------------
# Original Status: W
# Encoded Label: 1
# ------------
# Original Status: W
# Encoded Label: 1
# ------------
# Original Status: L
# Encoded Label: 0
# ------------
# Original Status: W
# Encoded Label: 1
# ------------
# Original Status: L
# Encoded Label: 0
# ------------
# Original Status: L
# Encoded Label: 0
# ------------
# Original Status: L
# Encoded Label: 0
# ------------
# Original Status: W
# Encoded Label: 1
# ------------
# Original Status: W
# Encoded Label: 1
# ------------
# Original Status: L
# Encoded Label: 0
# ------------
# Original Status: W
# Encoded Label: 1
# ------------
# Original Status: L
# Encoded Label: 0
# ------------
# Original Status: L
# Encoded Label: 0
# ------------
# Original Status: W
# Encoded Label: 1
# ------------
# Original Status: W
# Encoded Label: 1
# ------------
# Original Status: W
# Encoded Label: 1
# ------------
# Original Status: L
# Encoded Label: 0
# ------------
# Original Status: L
# Encoded Label: 0
# ------------
# Original Status: L
# Encoded Label: 0
# ------------
# Original Status: L
# Encoded Label: 0
# ------------
# Original Status: L
# Encoded Label: 0
# ------------
# Original Status: L
# Encoded Label: 0
# ------------
# Original Status: L
# Encoded Label: 0
# ------------
# Original Status: L
# Encoded Label: 0
# ------------
# Original Status: L
# Encoded Label: 0
# ------------
# Original Status: L
# Encoded Label: 0
# ------------
# Original Status: W
# Encoded Label: 1
# ------------
# Original Status: W
# Encoded Label: 1
# ------------
# Original Status: W
# Encoded Label: 1
# ------------
# Original Status: L
# Encoded Label: 0
# ------------
# Original Status: L
# Encoded Label: 0
# ------------
# Original Status: W
# Encoded Label: 1
# ------------
# Original Status: W
# Encoded Label: 1
# ------------
# Original Status: W
# Encoded Label: 1
# ------------
# Original Status: W
# Encoded Label: 1
# ------------
# Original Status: L
# Encoded Label: 0
# ------------
# Original Status: W
# Encoded Label: 1
# ------------
# Original Status: W
# Encoded Label: 1
# ------------
# Original Status: W
# Encoded Label: 1
# ------------
# Original Status: W
# Encoded Label: 1
# ------------
# Original Status: W
# Encoded Label: 1
# ------------
# Original Status: L
# Encoded Label: 0
# ------------
# Original Status: L
# Encoded Label: 0
# ------------
# Original Status: W
# Encoded Label: 1
# ------------
# Original Status: L
# Encoded Label: 0
# ------------
# Original Status: L
# Encoded Label: 0
# ------------
# Original Status: W
# Encoded Label: 1
# ------------
# Original Status: W
# Encoded Label: 1
# ------------
# Original Status: L
# Encoded Label: 0
# ------------
# Original Status: L
# Encoded Label: 0
# ------------
# Original Status: W
# Encoded Label: 1
# ------------
# Original Status: W
# Encoded Label: 1
# ------------
# Original Status: L
# Encoded Label: 0
# ------------
# Original Status: W
# Encoded Label: 1
# ------------
# Original Status: W
# Encoded Label: 1
# ------------
# Original Status: W
# Encoded Label: 1
# ------------
# Original Status: L
# Encoded Label: 0
# ------------
# Original Status: W
# Encoded Label: 1
# ------------
# Original Status: L
# Encoded Label: 0
# ------------
# Original Status: W
# Encoded Label: 1
# ------------
# Original Status: W
# Encoded Label: 1
# ------------
# Original Status: W
# Encoded Label: 1
# ------------
# Original Status: W
# Encoded Label: 1
# ------------
# Original Status: L
# Encoded Label: 0
# ------------
# Original Status: L
# Encoded Label: 0
# ------------
# Original Status: W
# Encoded Label: 1
# ------------
# Original Status: L
# Encoded Label: 0
# ------------
# Original Status: L
# Encoded Label: 0
# ------------
# Original Status: W
# Encoded Label: 1
# ------------
# Original Status: W
# Encoded Label: 1
# ------------
# Original Status: W
# Encoded Label: 1
# ------------
# Original Status: L
# Encoded Label: 0
# ------------
# Original Status: W
# Encoded Label: 1
# ------------
# Original Status: L
# Encoded Label: 0
# ------------
# Original Status: L
# Encoded Label: 0
# ------------
# Original Status: W
# Encoded Label: 1
# ------------
# Original Status: W
# Encoded Label: 1
# ------------
# Original Status: W
# Encoded Label: 1
# ------------
# Original Status: W
# Encoded Label: 1
# ------------
# Original Status: W
# Encoded Label: 1
# ------------
# Original Status: W
# Encoded Label: 1
# ------------
# Original Status: L
# Encoded Label: 0
# ------------
# Original Status: W
# Encoded Label: 1
# ------------
# Original Status: L
# Encoded Label: 0
# ------------
# Original Status: W
# Encoded Label: 1
# ------------
# Original Status: L
# Encoded Label: 0
# ------------
# Original Status: W
# Encoded Label: 1
# ------------
# Original Status: W
# Encoded Label: 1
# ------------
# Original Status: L
# Encoded Label: 0
# ------------
# Original Status: W
# Encoded Label: 1
# ------------
# Original Status: L
# Encoded Label: 0
# ------------
# Original Status: W
# Encoded Label: 1
# ------------
# Original Status: W
# Encoded Label: 1
# ------------
# Original Status: L
# Encoded Label: 0
# ------------
# Original Status: L
# Encoded Label: 0
# ------------
# Original Status: L
# Encoded Label: 0
# ------------
# Original Status: W
# Encoded Label: 1
# ------------
# Original Status: W
# Encoded Label: 1
# ------------
# Original Status: W
# Encoded Label: 1
# ------------
# Original Status: L
# Encoded Label: 0
# ------------
# Original Status: L
# Encoded Label: 0
# ------------
# Original Status: W
# Encoded Label: 1
# ------------
# Original Status: W
# Encoded Label: 1
# ------------
# Original Status: W
# Encoded Label: 1
# ------------
# Original Status: W
# Encoded Label: 1
# ------------
# Original Status: L
# Encoded Label: 0
# ------------
# Original Status: L
# Encoded Label: 0
# ------------
# Original Status: W
# Encoded Label: 1
# ------------
# Original Status: L
# Encoded Label: 0
# ------------
# Original Status: W
# Encoded Label: 1
# ------------
# Original Status: L
# Encoded Label: 0
# ------------
# Original Status: L
# Encoded Label: 0
# ------------
# Original Status: L
# Encoded Label: 0
# ------------
# Original Status: W
# Encoded Label: 1
# ------------
# Original Status: W
# Encoded Label: 1
# ------------
# Original Status: L
# Encoded Label: 0
# ------------
# Original Status: W
# Encoded Label: 1
# ------------
# Original Status: W
# Encoded Label: 1
# ------------
# Original Status: L
# Encoded Label: 0
# ------------
# Original Status: W
# Encoded Label: 1
# ------------
# Original Status: L
# Encoded Label: 0
# ------------
# Original Status: W
# Encoded Label: 1
# ------------
# Original Status: L
# Encoded Label: 0
# ------------
# Original Status: W
# Encoded Label: 1
# ------------
# Original Status: W
# Encoded Label: 1
# ------------
# Original Status: W
# Encoded Label: 1
# ------------
# Original Status: W
# Encoded Label: 1
# ------------
# Original Status: L
# Encoded Label: 0
# ------------
# Original Status: W
# Encoded Label: 1
# ------------
# Original Status: W
# Encoded Label: 1
# ------------
# Original Status: W
# Encoded Label: 1
# ------------
# Original Status: W
# Encoded Label: 1
# ------------
# Original Status: W
# Encoded Label: 1
# ------------
# Original Status: W
# Encoded Label: 1
# ------------
# Original Status: W
# Encoded Label: 1
# ------------
# Original Status: L
# Encoded Label: 0
# ------------
# Original Status: W
# Encoded Label: 1
# ------------
# Original Status: L
# Encoded Label: 0
# ------------
# Original Status: W
# Encoded Label: 1
# ------------
# Original Status: L
# Encoded Label: 0
# ------------
# Original Status: L
# Encoded Label: 0
# ------------
# Original Status: W
# Encoded Label: 1
# ------------
# Original Status: L
# Encoded Label: 0
# ------------
# Original Status: W
# Encoded Label: 1
# ------------
# Original Status: W
# Encoded Label: 1
# ------------
# Original Status: L
# Encoded Label: 0
# ------------
# Original Status: W
# Encoded Label: 1
# ------------
# Original Status: W
# Encoded Label: 1
# ------------
# Original Status: W
# Encoded Label: 1
# ------------
# Original Status: L
# Encoded Label: 0
# ------------
# Original Status: W
# Encoded Label: 1
# ------------
# Original Status: W
# Encoded Label: 1
# ------------
# Original Status: W
# Encoded Label: 1
# ------------
# Original Status: W
# Encoded Label: 1
# ------------
# Original Status: W
# Encoded Label: 1
# ------------
# Original Status: L
# Encoded Label: 0
# ------------
# Original Status: W
# Encoded Label: 1
# ------------
# Original Status: W
# Encoded Label: 1
# ------------
# Original Status: L
# Encoded Label: 0
# ------------
# Original Status: L
# Encoded Label: 0
# ------------
# Original Status: W
# Encoded Label: 1
# ------------
# Original Status: W
# Encoded Label: 1
# ------------
# Original Status: W
# Encoded Label: 1
# ------------
# Original Status: W
# Encoded Label: 1
# ------------
# Original Status: L
# Encoded Label: 0
# ------------
# Original Status: W
# Encoded Label: 1
# ------------
# Original Status: W
# Encoded Label: 1
# ------------
# Original Status: L
# Encoded Label: 0
# ------------
# Original Status: W
# Encoded Label: 1
# ------------
# Original Status: W
# Encoded Label: 1
# ------------
# Original Status: L
# Encoded Label: 0
# ------------
# Original Status: L
# Encoded Label: 0
# ------------
# Original Status: W
# Encoded Label: 1
# ------------
# Original Status: W
# Encoded Label: 1
# ------------
# Original Status: L
# Encoded Label: 0
# ------------
# Original Status: W
# Encoded Label: 1
# ------------
# Original Status: L
# Encoded Label: 0
# ------------
# Original Status: W
# Encoded Label: 1
# ------------
# Original Status: W
# Encoded Label: 1
# ------------
# Original Status: L
# Encoded Label: 0
# ------------
# Original Status: W
# Encoded Label: 1
# ------------
# Original Status: W
# Encoded Label: 1
# ------------
# Original Status: W
# Encoded Label: 1
# ------------
# Original Status: W
# Encoded Label: 1
# ------------
# Original Status: L
# Encoded Label: 0
# ------------
# Original Status: W
# Encoded Label: 1
# ------------
# Original Status: W
# Encoded Label: 1
# ------------
# Original Status: L
# Encoded Label: 0
# ------------
# Original Status: W
# Encoded Label: 1
# ------------
# Original Status: L
# Encoded Label: 0
# ------------
# Original Status: L
# Encoded Label: 0
# ------------
# Original Status: L
# Encoded Label: 0
# ------------
# Original Status: W
# Encoded Label: 1
# ------------
# Original Status: W
# Encoded Label: 1
# ------------
# Original Status: L
# Encoded Label: 0
# ------------
# Original Status: L
# Encoded Label: 0
# ------------
# Original Status: W
# Encoded Label: 1
# ------------
# Original Status: W
# Encoded Label: 1
# ------------
# Original Status: L
# Encoded Label: 0
# ------------
# Original Status: L
# Encoded Label: 0
# ------------
# Original Status: L
# Encoded Label: 0
# ------------
# Original Status: W
# Encoded Label: 1
# ------------
# Original Status: L
# Encoded Label: 0
# ------------
# Original Status: W
# Encoded Label: 1
# ------------
# Original Status: W
# Encoded Label: 1
# ------------
# Original Status: L
# Encoded Label: 0
# ------------
# Original Status: W
# Encoded Label: 1
# ------------
# Original Status: L
# Encoded Label: 0
# ------------
# Original Status: L
# Encoded Label: 0
# ------------
# Original Status: W
# Encoded Label: 1
# ------------
# Original Status: L
# Encoded Label: 0
# ------------
# Original Status: L
# Encoded Label: 0
# ------------
# Original Status: W
# Encoded Label: 1
# ------------
# Original Status: W
# Encoded Label: 1
# ------------
# Original Status: W
# Encoded Label: 1
# ------------
# Original Status: W
# Encoded Label: 1
# ------------
# Original Status: L
# Encoded Label: 0
# ------------
# Original Status: W
# Encoded Label: 1
# ------------
# Original Status: W
# Encoded Label: 1
# ------------
# Original Status: W
# Encoded Label: 1
# ------------
# Original Status: W
# Encoded Label: 1
# ------------
# Original Status: W
# Encoded Label: 1
# ------------
# Original Status: W
# Encoded Label: 1
# ------------
# Original Status: L
# Encoded Label: 0
# ------------
# Original Status: W
# Encoded Label: 1
# ------------
# Original Status: W
# Encoded Label: 1
# ------------
# Original Status: W
# Encoded Label: 1
# ------------
# Original Status: W
# Encoded Label: 1
# ------------
# Original Status: W
# Encoded Label: 1
# ------------
# Original Status: W
# Encoded Label: 1
# ------------
# Original Status: W
# Encoded Label: 1
# ------------
# Original Status: L
# Encoded Label: 0
# ------------
# Original Status: W
# Encoded Label: 1
# ------------
# Original Status: W
# Encoded Label: 1
# ------------
# Original Status: W
# Encoded Label: 1
# ------------
# Original Status: W
# Encoded Label: 1
# ------------
# Original Status: L
# Encoded Label: 0
# ------------
# Original Status: W
# Encoded Label: 1
# ------------
# Original Status: L
# Encoded Label: 0
# ------------
# Original Status: L
# Encoded Label: 0
# ------------
# Original Status: L
# Encoded Label: 0
# ------------
# Original Status: L
# Encoded Label: 0
# ------------
# Original Status: L
# Encoded Label: 0
# ------------
# Original Status: L
# Encoded Label: 0
# ------------
# Original Status: L
# Encoded Label: 0
# ------------
# Original Status: W
# Encoded Label: 1
# ------------
# Original Status: L
# Encoded Label: 0
# ------------
# Original Status: L
# Encoded Label: 0
# ------------
# Original Status: W
# Encoded Label: 1
# ------------
# Original Status: W
# Encoded Label: 1
# ------------
# Original Status: L
# Encoded Label: 0
# ------------
# Original Status: L
# Encoded Label: 0
# ------------
# Original Status: W
# Encoded Label: 1
# ------------
# Original Status: L
# Encoded Label: 0
# ------------
# Original Status: W
# Encoded Label: 1
# ------------
# Original Status: W
# Encoded Label: 1
# ------------
# Original Status: W
# Encoded Label: 1
# ------------
# Original Status: L
# Encoded Label: 0
# ------------
# Original Status: L
# Encoded Label: 0
# ------------
# Original Status: W
# Encoded Label: 1
# ------------
# Original Status: W
# Encoded Label: 1
# ------------
# Original Status: W
# Encoded Label: 1
# ------------
# Original Status: L
# Encoded Label: 0
# ------------
# Original Status: W
# Encoded Label: 1
# ------------
# Original Status: W
# Encoded Label: 1
# ------------
# Original Status: L
# Encoded Label: 0
# ------------
# Original Status: L
# Encoded Label: 0
# ------------
# Original Status: W
# Encoded Label: 1
# ------------
# Original Status: W
# Encoded Label: 1
# ------------
# Original Status: W
# Encoded Label: 1
# ------------
# Original Status: W
# Encoded Label: 1
# ------------
# Original Status: L
# Encoded Label: 0
# ------------
# Original Status: W
# Encoded Label: 1
# ------------
# Original Status: L
# Encoded Label: 0
# ------------
# Original Status: L
# Encoded Label: 0
# ------------
# Original Status: L
# Encoded Label: 0
# ------------
# Original Status: L
# Encoded Label: 0
# ------------
# Original Status: L
# Encoded Label: 0
# ------------
# Original Status: W
# Encoded Label: 1
# ------------
# Original Status: L
# Encoded Label: 0
# ------------
# Original Status: W
# Encoded Label: 1
# ------------
# Original Status: W
# Encoded Label: 1
# ------------
# Original Status: L
# Encoded Label: 0
# ------------
# Original Status: L
# Encoded Label: 0
# ------------
# Original Status: W
# Encoded Label: 1
# ------------
# Original Status: L
# Encoded Label: 0
# ------------
# Original Status: L
# Encoded Label: 0
# ------------
# Original Status: W
# Encoded Label: 1
# ------------
# Original Status: W
# Encoded Label: 1
# ------------
# Original Status: W
# Encoded Label: 1
# ------------
# Original Status: L
# Encoded Label: 0
# ------------
# Original Status: W
# Encoded Label: 1
# ------------
# Original Status: W
# Encoded Label: 1
# ------------
# Original Status: L
# Encoded Label: 0
# ------------
# Original Status: W
# Encoded Label: 1
# ------------
# Original Status: W
# Encoded Label: 1
# ------------
# Original Status: L
# Encoded Label: 0
# ------------
# Original Status: W
# Encoded Label: 1
# ------------
# Original Status: W
# Encoded Label: 1
# ------------
# Original Status: L
# Encoded Label: 0
# ------------
# Original Status: L
# Encoded Label: 0
# ------------
# Original Status: L
# Encoded Label: 0
# ------------
# Original Status: L
# Encoded Label: 0
# ------------
# Original Status: W
# Encoded Label: 1
# ------------
# Original Status: L
# Encoded Label: 0
# ------------
# Original Status: W
# Encoded Label: 1
# ------------
# Original Status: L
# Encoded Label: 0
# ------------
# Original Status: W
# Encoded Label: 1
# ------------
# Original Status: W
# Encoded Label: 1
# ------------
# Original Status: W
# Encoded Label: 1
# ------------
# Original Status: W
# Encoded Label: 1
# ------------
# Original Status: W
# Encoded Label: 1
# ------------

# %%
from keras.utils import to_categorical

# Step 2: One-hot encoding
one_hot_y = to_categorical(encoded_y)
one_hot_y
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-9-81831c234c0a> in <module>
# ----> 1 from keras.utils import to_categorical
#       2
#       3 # Step 2: One-hot encoding
#       4 one_hot_y = to_categorical(encoded_y)
#       5 one_hot_y
#
# ModuleNotFoundError: No module named 'keras'
